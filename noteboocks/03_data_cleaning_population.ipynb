# %%
import pandas as pd

populacao = pd.read_csv("populacao.csv", sep=";")
populacao.head()
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2026-01-28",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Population, total","SP.POP.TOTL",...
# 3  Africa Eastern and Southern,"AFE","Population,...
# 4  Afghanistan,"AFG","Population, total","SP.POP....

# %%
populacao = pd.read_csv("populacao.csv", skiprows=1)
populacao.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Last Updated Date  \
# ...

# %%
populacao.columns
# Out:
# Index(['Last Updated Date', '2026-01-28', 'Unnamed: 2'], dtype='object')

# %%
populacao.columns = populacao.columns.str.strip()

# %%
eu_countries = [
    "Austria", "Belgium", "Bulgaria", "Cyprus", "Czech Republic",
    "Germany", "Denmark", "Estonia", "Greece", "Spain",
    "Finland", "France", "Croatia", "Hungary", "Ireland",
    "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia",
    "Malta", "Netherlands", "Norway", "Poland", "Portugal",
    "Romania", "Sweden", "Slovenia", "Slovakia"
]

# %%
populacao.columns
# Out:
# Index(['Last Updated Date', '2026-01-28', 'Unnamed: 2'], dtype='object')

# %%
populacao = pd.read_csv("populacao.csv", skiprows=4)
populacao.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
populacao.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')

# %%
populacao_eu = populacao[populacao["Country Name"].isin(eu_countries)]

# %%
eu_countries = [
    "Austria", "Belgium", "Bulgaria", "Cyprus", "Czech Republic",
    "Germany", "Denmark", "Estonia", "Greece", "Spain",
    "Finland", "France", "Croatia", "Hungary", "Ireland",
    "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia",
    "Malta", "Netherlands", "Norway", "Poland", "Portugal",
    "Romania", "Sweden", "Slovenia", "Slovakia"
]

# %%
populacao_eu = populacao[
    populacao["Country Name"].isin(eu_countries)
]

# %%
sorted(populacao_eu["Country Name"].unique())
# Out:
# ['Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Slovenia',
#  'Spain',
#  'Sweden']

# %%
populacao_eu.to_csv("populacao_ue.csv", index=False)

# %%
populacao_eu.columns = populacao_eu.columns.str.strip()

# %%
populacao_eu = populacao_eu.drop(columns=[
    "Country Code",
    "Indicator Name",
    "Indicator Code"
])

# %%
anos_validos = [str(year) for year in range(1990, 2024)]

# %%
populacao_eu = populacao_eu[["Country Name"] + anos_validos]

# %%
populacao_eu.head()
populacao_eu.columns
# Out:
# Index(['Country Name', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
populacao_eu.to_csv("populacao_UNE.csv", index=False)

# %%
anos_validos = [str(year) for year in range(1990, 2024)]

populacao_eu[anos_validos] = populacao_eu[anos_validos].apply(
    pd.to_numeric, errors="coerce"
)

# %%
populacao_eu[anos_validos] = populacao_eu[anos_validos].astype("Int64")

# %%
populacao_eu.dtypes
populacao_eu.head()
# Out:
#    Country Name      1990      1991      1992      1993      1994      1995  \
# 14      Austria   7677850   7754891   7840709   7905633   7936118   7948278
# 17      Belgium   9967379  10004486  10045158  10084475  10115603  10136811
# 21     Bulgaria   8718289   8632367   8540164   8472313   8443591   8406067
# 53       Cyprus    788351    798944    810341    826034    844667    862695
# 55      Germany  79433029  80013896  80624598  81156363  81438348  81678051
#
#         1996      1997      1998  ...      2014      2015      2016      2017  \
# 14   7959017   7968041   7976789  ...   8546356   8642699   8736668   8797566
# 17  10156637  10181245  10203008  ...  11209057  11274196  11331422  11375158
# 21   8362826   8312068   8256786  ...   7073572   6984225   6894139   6803468
# 53    880290    897568    914548  ...   1201801   1219502   1237112   1254275
# 55  81914831  82034771  82047195  ...  80982500  81686611  82348669  82657002
#
# ...

# %%
populacao_eu.to_csv("populacao_une.csv", index=False)

# %%
populacao_eu.columns
# Out:
# Index(['Country Name', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
populacao_eu["dif_1990_2023"] = (
    populacao_eu["2023"] - populacao_eu["1990"]
)

# %%
populacao_eu[["Country Name", "1990", "2023", "dif_1990_2023"]].head()
# Out:
#    Country Name      1990      2023  dif_1990_2023
# 14      Austria   7677850   9131761        1453911
# 17      Belgium   9967379  11779946        1812567
# 21     Bulgaria   8718289   6446596       -2271693
# 53       Cyprus    788351   1344976         556625
# 55      Germany  79433029  83287273        3854244

# %%
populacao_eu.to_csv("populacao_ue.csv", index=False)
